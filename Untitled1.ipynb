# %%
# !python launch_gher.py --epochs 1000 --env fetchreach
# !python launch_gher.py --epochs 1000 --relabel --n_sampled_latents 1 --env fetchreach
# !python launch_gher.py --epochs 1000 --relabel --n_sampled_latents 100 --use_advantages --env fetchreach
# !python launch_gher.py --epochs 1000 --relabel --n_sampled_latents 100 --use_advantages --env fetchreach --cache --irl
# Out:
# doodad not detected
# objc[5133]: Class GLFWApplicationDelegate is implemented in both /Users/shanliyu/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1a1f289778) and /Users/shanliyu/anaconda3/lib/python3.6/site-packages/glfw/libglfw.3.dylib (0x1a1f30a740). One of the two will be used. Which one is undefined.
# objc[5133]: Class GLFWWindowDelegate is implemented in both /Users/shanliyu/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1a1f289700) and /Users/shanliyu/anaconda3/lib/python3.6/site-packages/glfw/libglfw.3.dylib (0x1a1f30a768). One of the two will be used. Which one is undefined.
# objc[5133]: Class GLFWContentView is implemented in both /Users/shanliyu/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1a1f2897a0) and /Users/shanliyu/anaconda3/lib/python3.6/site-packages/glfw/libglfw.3.dylib (0x1a1f30a7b8). One of the two will be used. Which one is undefined.
# ...
