# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# !python launch_gher.py --epochs 300 --env pointreacherobs
# !python launch_gher.py --epochs 300 --relabel --n_sampled_latents 1 --env pointreacherobs
# !python launch_gher.py --epochs 300 --relabel --n_sampled_latents 100 --use_advantages --env pointreacherobs
# !python launch_gher.py --epochs 300 --relabel --n_sampled_latents 100 --use_advantages --env pointreacherobs --cache --irl

# %%
df_no_r = pd.read_csv('/Users/shanliyu/School/CSE257/own/generalized-hindsight/data/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20_2021_05_25_10_24_59_0000--s-10/progress.csv')
df_rr   = pd.read_csv('/Users/shanliyu/School/CSE257/own/generalized-hindsight/data/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20_2021_05_25_11_48_41_0000--s-10/progress.csv')
df_air  = pd.read_csv('/Users/shanliyu/School/CSE257/own/generalized-hindsight/data/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20_2021_05_25_13_12_33_0000--s-10/progress.csv')
df_ar   = pd.read_csv('/Users/shanliyu/School/CSE257/own/generalized-hindsight/data/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20/gher-pointreacherobs-SAC-100e-20s-disc0.97-horizon20_2021_05_25_14_32_26_0000--s-10/progress.csv')

# %%
df_no_r.columns.tolist()
# Out:
# ['replay_buffer/size',
#  'trainer/QF1 Loss',
#  'trainer/QF2 Loss',
#  'trainer/Policy Loss',
#  'trainer/Q1 Predictions Mean',
#  'trainer/Q1 Predictions Std',
#  'trainer/Q1 Predictions Max',
#  'trainer/Q1 Predictions Min',
#  'trainer/Q2 Predictions Mean',
#  'trainer/Q2 Predictions Std',
#  'trainer/Q2 Predictions Max',
#  'trainer/Q2 Predictions Min',
#  'trainer/Q Targets Mean',
#  'trainer/Q Targets Std',
#  'trainer/Q Targets Max',
#  'trainer/Q Targets Min',
#  'trainer/Log Pis Mean',
#  'trainer/Log Pis Std',
#  'trainer/Log Pis Max',
#  'trainer/Log Pis Min',
#  'trainer/Policy mu Mean',
#  'trainer/Policy mu Std',
#  'trainer/Policy mu Max',
#  'trainer/Policy mu Min',
#  'trainer/Policy log std Mean',
#  'trainer/Policy log std Std',
#  'trainer/Policy log std Max',
#  'trainer/Policy log std Min',
#  'trainer/Alpha',
#  'trainer/Alpha Loss',
#  'exploration/num steps total',
#  'exploration/num paths total',
#  'exploration/path length Mean',
#  'exploration/path length Std',
#  'exploration/path length Max',
#  'exploration/path length Min',
#  'exploration/Rewards Mean',
#  'exploration/Rewards Std',
#  'exploration/Rewards Max',
#  'exploration/Rewards Min',
#  'exploration/Returns Mean',
#  'exploration/Returns Std',
#  'exploration/Returns Max',
#  'exploration/Returns Min',
#  'exploration/Actions Mean',
#  'exploration/Actions Std',
#  'exploration/Actions Max',
#  'exploration/Actions Min',
#  'exploration/Num Paths',
#  'exploration/Average Returns',
#  'exploration/env_infos/final/reward_dist Mean',
#  'exploration/env_infos/final/reward_dist Std',
#  'exploration/env_infos/final/reward_dist Max',
#  'exploration/env_infos/final/reward_dist Min',
#  'exploration/env_infos/initial/reward_dist Mean',
#  'exploration/env_infos/initial/reward_dist Std',
#  'exploration/env_infos/initial/reward_dist Max',
#  'exploration/env_infos/initial/reward_dist Min',
#  'exploration/env_infos/reward_dist Mean',
#  'exploration/env_infos/reward_dist Std',
#  'exploration/env_infos/reward_dist Max',
#  'exploration/env_infos/reward_dist Min',
#  'exploration/env_infos/final/reward_energy Mean',
#  'exploration/env_infos/final/reward_energy Std',
#  'exploration/env_infos/final/reward_energy Max',
#  'exploration/env_infos/final/reward_energy Min',
#  'exploration/env_infos/initial/reward_energy Mean',
#  'exploration/env_infos/initial/reward_energy Std',
#  'exploration/env_infos/initial/reward_energy Max',
#  'exploration/env_infos/initial/reward_energy Min',
#  'exploration/env_infos/reward_energy Mean',
#  'exploration/env_infos/reward_energy Std',
#  'exploration/env_infos/reward_energy Max',
#  'exploration/env_infos/reward_energy Min',
#  'exploration/env_infos/final/reward_safety Mean',
#  'exploration/env_infos/final/reward_safety Std',
#  'exploration/env_infos/final/reward_safety Max',
#  'exploration/env_infos/final/reward_safety Min',
#  'exploration/env_infos/initial/reward_safety Mean',
#  'exploration/env_infos/initial/reward_safety Std',
#  'exploration/env_infos/initial/reward_safety Max',
#  'exploration/env_infos/initial/reward_safety Min',
#  'exploration/env_infos/reward_safety Mean',
#  'exploration/env_infos/reward_safety Std',
#  'exploration/env_infos/reward_safety Max',
#  'exploration/env_infos/reward_safety Min',
#  'exploration/env_infos/final/end_effector_loc Mean',
#  'exploration/env_infos/final/end_effector_loc Std',
#  'exploration/env_infos/final/end_effector_loc Max',
#  'exploration/env_infos/final/end_effector_loc Min',
#  'exploration/env_infos/initial/end_effector_loc Mean',
#  'exploration/env_infos/initial/end_effector_loc Std',
#  'exploration/env_infos/initial/end_effector_loc Max',
#  'exploration/env_infos/initial/end_effector_loc Min',
#  'exploration/env_infos/end_effector_loc Mean',
#  'exploration/env_infos/end_effector_loc Std',
#  'exploration/env_infos/end_effector_loc Max',
#  'exploration/env_infos/end_effector_loc Min',
#  'evaluation/num steps total',
#  'evaluation/num paths total',
#  'evaluation/path length Mean',
#  'evaluation/path length Std',
#  'evaluation/path length Max',
#  'evaluation/path length Min',
#  'evaluation/Rewards Mean',
#  'evaluation/Rewards Std',
#  'evaluation/Rewards Max',
#  'evaluation/Rewards Min',
#  'evaluation/Returns Mean',
#  'evaluation/Returns Std',
#  'evaluation/Returns Max',
#  'evaluation/Returns Min',
#  'evaluation/Actions Mean',
#  'evaluation/Actions Std',
#  'evaluation/Actions Max',
#  'evaluation/Actions Min',
#  'evaluation/Num Paths',
#  'evaluation/Average Returns',
#  'evaluation/env_infos/final/reward_dist Mean',
#  'evaluation/env_infos/final/reward_dist Std',
#  'evaluation/env_infos/final/reward_dist Max',
#  'evaluation/env_infos/final/reward_dist Min',
#  'evaluation/env_infos/initial/reward_dist Mean',
#  'evaluation/env_infos/initial/reward_dist Std',
#  'evaluation/env_infos/initial/reward_dist Max',
#  'evaluation/env_infos/initial/reward_dist Min',
#  'evaluation/env_infos/reward_dist Mean',
#  'evaluation/env_infos/reward_dist Std',
#  'evaluation/env_infos/reward_dist Max',
#  'evaluation/env_infos/reward_dist Min',
#  'evaluation/env_infos/final/reward_energy Mean',
#  'evaluation/env_infos/final/reward_energy Std',
#  'evaluation/env_infos/final/reward_energy Max',
#  'evaluation/env_infos/final/reward_energy Min',
#  'evaluation/env_infos/initial/reward_energy Mean',
#  'evaluation/env_infos/initial/reward_energy Std',
#  'evaluation/env_infos/initial/reward_energy Max',
#  'evaluation/env_infos/initial/reward_energy Min',
#  'evaluation/env_infos/reward_energy Mean',
#  'evaluation/env_infos/reward_energy Std',
#  'evaluation/env_infos/reward_energy Max',
#  'evaluation/env_infos/reward_energy Min',
#  'evaluation/env_infos/final/reward_safety Mean',
#  'evaluation/env_infos/final/reward_safety Std',
#  'evaluation/env_infos/final/reward_safety Max',
#  'evaluation/env_infos/final/reward_safety Min',
#  'evaluation/env_infos/initial/reward_safety Mean',
#  'evaluation/env_infos/initial/reward_safety Std',
#  'evaluation/env_infos/initial/reward_safety Max',
#  'evaluation/env_infos/initial/reward_safety Min',
#  'evaluation/env_infos/reward_safety Mean',
#  'evaluation/env_infos/reward_safety Std',
#  'evaluation/env_infos/reward_safety Max',
#  'evaluation/env_infos/reward_safety Min',
#  'evaluation/env_infos/final/end_effector_loc Mean',
#  'evaluation/env_infos/final/end_effector_loc Std',
#  'evaluation/env_infos/final/end_effector_loc Max',
#  'evaluation/env_infos/final/end_effector_loc Min',
#  'evaluation/env_infos/initial/end_effector_loc Mean',
#  'evaluation/env_infos/initial/end_effector_loc Std',
#  'evaluation/env_infos/initial/end_effector_loc Max',
#  'evaluation/env_infos/initial/end_effector_loc Min',
#  'evaluation/env_infos/end_effector_loc Mean',
#  'evaluation/env_infos/end_effector_loc Std',
#  'evaluation/env_infos/end_effector_loc Max',
#  'evaluation/env_infos/end_effector_loc Min',
#  'time/data storing (s)',
#  'time/evaluation sampling (s)',
#  'time/exploration sampling (s)',
#  'time/logging (s)',
#  'time/saving (s)',
#  'time/training (s)',
#  'time/epoch (s)',
#  'time/total (s)',
#  'Epoch']

# %%
name = 'evaluation/Average Returns'
plt.plot(df_no_r['evaluation/num steps total'], df_no_r[name], label="No Relabeling")
plt.plot(df_no_r['evaluation/num steps total'], df_rr[name], label="Random Relabeling")
plt.plot(df_no_r['evaluation/num steps total'], df_air[name], label="AIR")
plt.plot(df_no_r['evaluation/num steps total'], df_ar[name], label="AR")
plt.legend()
